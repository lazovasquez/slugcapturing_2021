# %% [markdown]
# # Input codes
# > Import notebooks

# %%
# Basic notebooks
# %run ./codes/00_libraries.ipynb
# %run ./codes/01_constants_codes.ipynb
# %run ./codes/02_constants_test_cases.ipynb

# Equations
# %run ./05_C_testcases.ipynb
# %run ./codes/06_testcases_conditions.ipynb
# %run ./codes/07_equations_functions.ipynb
# %run ./codes/08_equations_matrices.ipynb

# Stability
# %run ./codes/10_stability_functions.ipynb
# %run ./codes/11_reference_conditions.ipynb

# Finite element methods
# %run ./codes/18_initial_boundary_conditions.ipynb
# %run ./codes/19_fem_discretization.ipynb
# %run ./codes/20_variational_form.ipynb
# %run ./codes/21_transient_solvers.ipynb

# Nonlinear simulations
# %run ./codes/24_fully_discretized.ipynb
# Out:
# variable1_n =  [0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626]
# Iteration : 1 of 1
# Time      : 1.7887670545583635e-05 s
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
# variable1_n1 =  [0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626]
#   Newton iteration 0: r (abs) = 8.721e+08 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 1.418e-07 (tol = 1.000e-10) r (rel) = 1.626e-16 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17467/506553186.py:653: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/transient/eigenspectrum/fig1.pdf',

# %%
print(vert_variable1_n)
# Out:
# [0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626]

# %%
print(vert_variable1_n1)
# Out:
# [0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626 0.50253626
#  0.50253626 0.50253626 0.50253626 0.50253626 0.50253626]
