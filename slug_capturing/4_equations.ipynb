# %% [markdown]
# ## _Equations_
# Compressible two-fluid model of Montini (2011)
#
# 1. Reference state (find var1)
# 2. Reference state (find j_l)
# 3. reference state (Fenics)
# 4. Linear matrices (Primitive variables)
# 5. Linear matrices (Conserved variables)

# %% [markdown]
# ## Previous operations

# %%
A = pi*pow (D, 2.)/4. # mˆ2, total area

# %% [markdown]
# ## Conditions of equations

# %%
# Body force
if dirichlet_type == "nonperiodic": 
    Fbody = 0
elif dirichlet_type == "periodic": 
    Fbody = 74.225

# %% [markdown]
# ## 1. Reference state
# find var1

# %%
# def ref_state (j_l, j_g, var4_0, beta, rho_l, p_factor, mu_l, mu_g, D):
#     # Area
#     A = DOLFIN_PI*D**2./4.0# mˆ2, total area
#     # liquid sectional area
#     def A_l (var1):
#         return A*var1
#     # gas sectional area
#     def A_g (var1):
#         return A*(1 - var1)
#     # stratification angle
#     def gamma (var1):
#         return DOLFIN_PI*(var1 + DOLFIN_EPS) + pow ((3.*DOLFIN_PI/2.), (1./3.))*(1 - 2*(var1 + DOLFIN_EPS) + pow (abs (var1 + DOLFIN_EPS), (1./3.)) - pow (abs(1 - (var1 + DOLFIN_EPS)), (1/3))) - (1/200)*(1 - (var1 + DOLFIN_EPS))*(var1 + DOLFIN_EPS)*(1 - 2*(var1 + DOLFIN_EPS))*(1+4*((1 - (var1 + DOLFIN_EPS))**2 + (var1 +  + DOLFIN_EPS)**2))
#     # liquid wetted perimeter
#     def P_lw (var1):
#         return D*gamma (var1)
#     # gas wetted perimeter
#     def P_gw (var1):
#         return D*(DOLFIN_PI - gamma (var1))
#     # interface wetted perimeter
#     def P_gl (var1):
#         return D*np.sin (gamma (var1))
#     # liquid hydraulic diameter 
#     def Dh_l (var1):
#         return 4.*A_l (var1)/P_lw (var1)
#     # gas hydraulic diameter 
#     def Dh_g (var1):
#         return 4.*A_g (var1)/(P_gw (var1) + P_gl (var1))
#     # Gas density
#     def rho_g (var4):
#         return p_factor*var4 + DOLFIN_EPS
#     # liquid phase velocity
#     def var2 (var1):
#         return j_l/(var1)
#     # gas phase velocity
#     def var3 (var1):
#         return j_g/(1 - var1)
#     # liquid Reynolds number
#     def Re_l (var1, var2):
#         return rho_l*var2*Dh_l (var1)/mu_l
#     # gas Reynolds number
#     def Re_g (var1, var3, var4):
#         return rho_g (var4)*var3*Dh_g (var1)/mu_g
#     # interface hydraulic diameter and Reynolds number
#     def Dh_gl (var1):
#         return 4.*A_g (var1)/(P_gw (var1) + P_gl (var1))
#     def Re_gl (var1, var2, var3, var4):
#         return rho_g (var4)*abs(var3 - var2)*Dh_gl (var1)/mu_g
#     # Friction factor liquid-wall
#     def f_lw (var1, var2):
#         return 0.046*abs(Re_l (var1, var2))**(-0.2)
#     # Friction factor gas-wall
#     def f_gw (var1, var3, var4):
#         return 0.046*abs(Re_g (var1, var3, var4))**(-0.2)
#     # interfacial friction
#     def f_gl (var1, var2, var3, var4):
#         return max (f_gw (var1, var3, var4), 0.014)
#     # Shear stress liquid-wall
#     def tau_lw (var1, var2):
#         return 1/2*f_lw (var1, var2)*rho_l*var2*abs (var2)
#     # Shear stress gas-wall
#     def tau_gw (var1, var3, var4):
#         return 1/2*f_gw (var1, var3, var4)*rho_g (var4)*var3*abs (var3)
#     # interface shear stress
#     def tau_gl (var1, var2, var3, var4):
#         return 1/2*f_gl(var1, var2, var3, var4)*rho_g (var4)*(var3 - var2)*abs (var3 - var2)

#     # Equilibrium
#     def equilibrium1 (var1): 
#         return (rho_g (var4_0) - rho_l)*g*np.sin (beta) - tau_lw (var1, var2 (var1))*P_lw (var1)/A_l (var1) + tau_gw (var1, var3 (var1), var4_0)*P_gw (var1)/A_g (var1) + tau_gl (var1, var2 (var1), var3 (var1), var4_0)*P_gl (var1)*(1/A_l (var1) + 1/A_g (var1))
#     # Reference state
#     var1_ref = brenth (equilibrium1, lima, limb)
#     var2_ref = j_l/var1_ref
#     var3_ref = j_g/(1 - var1_ref)
#     var4_ref = var4_0

#     ref = np.array ([var1_ref, var2_ref, var3_ref, var4_ref])
#     # Reynolds number of initial conditions
#     Rel_ref = Re_l (var1_ref, var2_ref)
#     Reg_ref = Re_g (var1_ref, var3_ref, var4_ref)
#     Regl_ref = Re_gl (var1_ref, var2_ref, var3_ref, var4_ref)

#     # Reynolds reference conditions
#     Re_ref = np.array ([Rel_ref, Reg_ref, Regl_ref])

#     return ref, Re_ref

# # FUNCTION:
# # ref, Re_ref = ref_state (j_l, j_g, var4_0, beta, rho_l, p_factor, mu_l, mu_g, D)

# %% [markdown]
# ## 2. Reference state
# Find j_l

# %%
# # ===============================================================
# # REFERENCE STATE (FIND j_l)
# # ===============================================================
# def ref_state_jl (var1, j_g, var4_0, beta, rho_l, p_factor, mu_l, mu_g, D):
# # Area
#     A = DOLFIN_PI*D**2./4.0# mˆ2, total area
#     # liquid sectional area
#     def A_l (var1):
#         return A*var1
#     # gas sectional area
#     def A_g (var1):
#         return A*(1 - var1)
#     # stratification angle
#     def gamma (var1):
#         return DOLFIN_PI*(var1 + DOLFIN_EPS) + pow ((3.*DOLFIN_PI/2.), (1./3.))*(1 - 2*(var1 + DOLFIN_EPS) + pow (abs (var1 + DOLFIN_EPS), (1./3.)) - pow (abs(1 - (var1 + DOLFIN_EPS)), (1/3))) - (1/200)*(1 - (var1 + DOLFIN_EPS))*(var1 + DOLFIN_EPS)*(1 - 2*(var1 + DOLFIN_EPS))*(1+4*((1 - (var1 + DOLFIN_EPS))**2 + (var1 +  + DOLFIN_EPS)**2))
#     # liquid wetted perimeter
#     def P_lw (var1):
#         return D*gamma (var1)
#     # gas wetted perimeter
#     def P_gw (var1):
#         return D*(DOLFIN_PI - gamma (var1))
#     # interface wetted perimeter
#     def P_gl (var1):
#         return D*np.sin (gamma (var1))
#     # liquid hydraulic diameter 
#     def Dh_l (var1):
#         return 4.*A_l (var1)/P_lw (var1)
#     # gas hydraulic diameter 
#     def Dh_g (var1):
#         return 4.*A_g (var1)/(P_gw (var1) + P_gl (var1))
#     # Gas density
#     def rho_g (var4):
#         return p_factor*var4 + DOLFIN_EPS
#     # gas phase velocity
#     def var3 (var1):
#         return j_g/(1 - var1)
#     # liquid Reynolds number
#     def Re_l (var1, var2):
#         return rho_l*var2*Dh_l (var1)/mu_l
#     # gas Reynolds number
#     def Re_g (var1, var3, var4):
#         return rho_g (var4)*var3*Dh_g (var1)/mu_g
#     # interface hydraulic diameter and Reynolds number
#     def Dh_gl (var1):
#         return 4.*A_g (var1)/(P_gw (var1) + P_gl (var1))
#     def Re_gl (var1, var2, var3, var4):
#         return rho_g (var4)*abs(var3 - var2)*Dh_gl (var1)/mu_g
#     # Friction factor liquid-wall
#     def f_lw (var1, var2):
#         return 0.046*abs(Re_l (var1, var2))**(-0.2)
#     # Friction factor gas-wall
#     def f_gw (var1, var3, var4):
#         return 0.046*abs(Re_g (var1, var3, var4))**(-0.2)
#     # interfacial friction
#     def f_gl (var1, var2, var3, var4):
#         return max (f_gw (var1, var3, var4), 0.014)
#     # Shear stress liquid-wall
#     def tau_lw (var1, var2):
#         return 1/2*f_lw (var1, var2)*rho_l*var2*abs (var2)
#     # Shear stress gas-wall
#     def tau_gw (var1, var3, var4):
#         return 1/2*f_gw (var1, var3, var4)*rho_g (var4)*var3*abs (var3)
#     # interface shear stress
#     def tau_gl (var1, var2, var3, var4):
#         return 1/2*f_gl(var1, var2, var3, var4)*rho_g (var4)*(var3 - var2)*abs (var3 - var2)

#     # liquid phase velocity
#     def var2b (j_l):
#         return j_l/(var1)
#     # Equilibrium
#     def equilibrium2 (j_l):  
#         return (rho_g (var4_0) - rho_l)*g*np.sin (beta) - tau_lw (var1, var2b (j_l))*P_lw (var1)/A_l (var1) + tau_gw (var1, var3 (var1), var4_0)*P_gw (var1)/A_g (var1) + tau_gl (var1, var2b (j_l), var3 (var1), var4_0)*P_gl (var1)*(1/A_l (var1) + 1/A_g (var1))
#     # Define j_l
#     j_l = fsolve (equilibrium2, x0) #Python function    

#     var1_ref = var1
#     var2_ref = j_l[0]/var1_ref
#     var3_ref = j_g/(1 - var1_ref)
#     var4_ref = var4_0

#     return np.array ([var1_ref, var2_ref, var3_ref, var4_ref])

# %% [markdown]
# ## 3. Reference state
# Fenics

# %%
# def rho_g_fenics (variable4):
#     return p_factor*variable4 + DOLFIN_EPS

# def A_l_fenics (variable1):
#     return A*variable1

# def A_g_fenics (variable1):
#     return A*(1 - variable1)

# def P_lw_fenics (variable1):
#     return D*gamma_fenics (variable1)

# def P_gw_fenics (variable1):
#     return D*(DOLFIN_PI - gamma_fenics (variable1))

# def P_gl_fenics (variable1):
#     return D*sin (gamma_fenics (variable1))

# def Dh_l_fenics (variable1):
#     return 4.*A_l_fenics (variable1)/P_lw_fenics (variable1)

# def Dh_g_fenics (variable1):
#     return 4.*A_g_fenics (variable1)/(P_gw_fenics (variable1) + P_gl_fenics (variable1))

# def Dh_gl_fenics (variable1):
#     return 4.*A_g_fenics (variable1)/(P_gw_fenics (var1iable) + P_gl_fenics (variable1))

# def Re_l_fenics (variable1, variable2):
#     return rho_l*variable2*Dh_l_fenics (variable1)/mu_l

# def Re_g_fenics (variable1, variable3, variable4):
#     return rho_g_fenics (variable4)*variable3*Dh_g_fenics (variable1)/mu_g

# def Re_gl_fenics (variable1, variable2, variable3, variable4):
#     return rho_g_fenics (variable4)*abs(variable3 - variable2)*Dh_gl_fenics (variable1)/mu_g

# def f_lw_fenics (variable1, variable2):
#     return 0.046*abs(Re_l_fenics (variable1, variable2))**(-0.2)

# def f_gw_fenics (variable1, variable3, variable4):
#     return 0.046*abs(Re_g_fenics (variable1, variable3, variable4))**(-0.2)

# def f_gl_fenics (variable1, variable2, variable3, variable4):
#     return Max (f_gw_fenics (variable1, variable3, variable4), 0.014)

# def tau_lw_fenics (variable1, variable2):
#     return 1/2*f_lw_fenics (variable1, variable2)*rho_l*variable2*abs (variable2)

# def tau_gw_fenics (variable1, variable3, variable4):
#     return 1/2*f_gw_fenics (variable1, variable3, variable4)*rho_g_fenics (variable4)*variable3*abs (variable3)

# def tau_gl_fenics (variable1, variable2, variable3, variable4):
#     return 1/2*f_gl_fenics (variable1, variable2, variable3, variable4)*rho_g_fenics (variable4)*(variable3 - variable2)*abs (variable3 - variable2)

# # ===============================================================
# # VARIABLES: reference state
# # ===============================================================
# # steady state momentum equation for e34-=horizontal steady state (characteristics and fourier). var4 is known, compute var1
# # def equilibrium1 (var1): 
# #     return (rho_g (var4_0) - rho_l)*g*np.sin (beta) - tau_lw (var1, var2 (var1))*P_lw (var1)/A_l (var1) + tau_gw (var1, var3 (var1), var4_0)*P_gw (var1)/A_g (var1) + tau_gl (var1, var2 (var1), var3 (var1), var4_0)*P_gl (var1)*(1/A_l (var1) + 1/A_g (var1))

# # liquid phase velocity
# def var2b (j_l):
#     return j_l/(var1)

# # stady state momentum equation for horizontal steady state (characteristics and fourier). var4 is known, compute j_l
# def equilibrium2 (j_l):  
#     return (rho_g (var4) - rho_l)*g*np.sin (beta) - tau_lw (var1, var2b (j_l))*P_lw (var1)/A_l (var1) + tau_gw (var1, var3 (var1), var4)*P_gw (var1)/A_g (var1) + tau_gl (var1, var2b (j_l), var3 (var1), var4)*P_gl (var1)*(1/A_l (var1) + 1/A_g (var1))

# %% [markdown]
# ## 4. Linear matrices
# Primitive variables

# %%
# # ===============================================================
# # LINEAR MATRICES
# # ===============================================================
# def linear_matrices_function (var1, var2, var3, var4, beta, D, system, rho_l, p_factor, mu_l, mu_g, dirichlet_type):
#     # Define body force
#     if dirichlet_type == "nonperiodic": 
#         Fbody = 0
#     elif dirichlet_type == "periodic": 
#         Fbody = 74.225
#     # Define equation system
#     # if any ([system == "system_1", system == "system_3"]):        
#     # stratification angle
#     def gamma (var1):
#         return DOLFIN_PI*(var1 + DOLFIN_EPS) + pow ((3.*DOLFIN_PI/2.), (1./3.))*(1 - 2*(var1 + DOLFIN_EPS) + pow (abs (var1 + DOLFIN_EPS), (1./3.)) - pow (abs(1 - (var1 + DOLFIN_EPS)), (1/3))) - (1/200)*(1 - (var1 + DOLFIN_EPS))*(var1 + DOLFIN_EPS)*(1 - 2*(var1 + DOLFIN_EPS))*(1+4*((1 - (var1 + DOLFIN_EPS))**2 + (var1 +  + DOLFIN_EPS)**2))
#     # Critic diameter
#     def Dc (var1):
#         return g*np.cos (beta)*DOLFIN_PI*D/(4*np.sin (gamma (var1)))
#     # Area
#     A = DOLFIN_PI*D**2./4.0# mˆ2, total area
#     # liquid sectional area
#     def A_l (var1):
#         return A*var1
#     # gas sectional area
#     def A_g (var1):
#         return A*(1 - var1)
#     # liquid wetted perimeter
#     def P_lw (var1):
#         return D*gamma (var1)
#     # gas wetted perimeter
#     def P_gw (var1):
#         return D*(DOLFIN_PI - gamma (var1))
#     # interface wetted perimeter
#     def P_gl (var1):
#         return D*np.sin (gamma (var1))
#     # liquid hydraulic diameter 
#     def Dh_l (var1):
#         return 4.*A_l (var1)/P_lw (var1)
#     # gas hydraulic diameter 
#     def Dh_g (var1):
#         return 4.*A_g (var1)/(P_gw (var1) + P_gl (var1))
#     # Gas density
#     def rho_g (var4):
#         return p_factor*var4 + DOLFIN_EPS
#     # liquid Reynolds number
#     def Re_l (var1, var2):
#         return rho_l*var2*Dh_l (var1)/mu_l
#     # gas Reynolds number
#     def Re_g (var1, var3, var4):
#         return rho_g (var4)*var3*Dh_g (var1)/mu_g
#     # interface hydraulic diameter and Reynolds number
#     def Dh_gl (var1):
#         return 4.*A_g (var1)/(P_gw (var1) + P_gl (var1))
#     def Re_gl (var1, var2, var3, var4):
#         return rho_g (var4)*abs(var3 - var2)*Dh_gl (var1)/mu_g
#     # Friction factor liquid-wall
#     def f_lw (var1, var2):
#         return 0.046*abs(Re_l (var1, var2))**(-0.2)
#     # Friction factor gas-wall
#     def f_gw (var1, var3, var4):
#         return 0.046*abs(Re_g (var1, var3, var4))**(-0.2)
#     # interfacial friction
#     def f_gl (var1, var2, var3, var4):
#         return max (f_gw (var1, var3, var4), 0.014)
#     # Shear stress liquid-wall
#     def tau_lw (var1, var2):
#         return 1/2*f_lw (var1, var2)*rho_l*var2*abs (var2)
#     # Shear stress gas-wall
#     def tau_gw (var1, var3, var4):
#         return 1/2*f_gw (var1, var3, var4)*rho_g (var4)*var3*abs (var3)
#     # interface shear stress
#     def tau_gl (var1, var2, var3, var4):
#         return 1/2*f_gl(var1, var2, var3, var4)*rho_g (var4)*(var3 - var2)*abs (var3 - var2)

#     if any ([system == "system_1", system == "system_3"]):        

#         # ===============================================================
#         # 1 - QUASILINEAR SYSTEM 
#         # W = (alpha_l, u_l, u_g, p_i)
#         # A != I
#         # ===============================================================
#         # Matrices
#         # Amat
#         def A11 (var1 ,var2, var3, var4):
#             return rho_l
#         def A12 (var1 ,var2, var3, var4):
#             return 0
#         def A13 (var1 ,var2, var3, var4):
#             return 0
#         def A14 (var1 ,var2, var3, var4):
#             return 0
        
#         # def A11_fenics (variable1 ,variable2, variable3, variable4):
#         #     return rho_l
#         # def A12_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def A13_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def A14_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)

#         #####
#         def A21 (var1 ,var2, var3, var4):
#             return -rho_g (var4)
#         def A22 (var1 ,var2, var3, var4):
#             return 0
#         def A23 (var1 ,var2, var3, var4):
#             return 0
#         def A24 (var1 ,var2, var3, var4):
#             return p_factor*(1 - var1)
        
#         # def A21_fenics (variable1 ,variable2, variable3, variable4):
#         #     return -rho_g_fenics (variable4)
#         # def A22_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def A23_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def A24_fenics (variable1 ,variable2, variable3, variable4):
#         #     return p_factor*(1 - variable1)

#         #####
#         def A31 (var1 ,var2, var3, var4):
#             return rho_l*var2
#         def A32 (var1 ,var2, var3, var4):
#             return rho_l*var1
#         def A33 (var1 ,var2, var3, var4):
#             return 0
#         def A34 (var1 ,var2, var3, var4):
#             return 0
        
#         # def A31_fenics (variable1 ,variable2, variable3, variable4):
#         #     return rho_l*variable2
#         # def A32_fenics (variable1 ,variable2, variable3, variable4):
#         #     return rho_l*variable1
#         # def A33_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def A34_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         #####
#         def A41 (var1 ,var2, var3, var4):
#             return -rho_g (var4)*var3
#         def A42 (var1 ,var2, var3, var4):
#             return 0
#         def A43 (var1 ,var2, var3, var4):
#             return rho_g (var4)*(1 - var1)
#         def A44 (var1 ,var2, var3, var4):
#             return p_factor*(1 - var1)*var3

#         # def A41_fenics (variable1 ,variable2, variable3, variable4):
#         #     return -rho_g_fenics (variable4)*variable3
#         # def A42_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def A43_fenics (variable1 ,variable2, variable3, variable4):
#         #     return rho_g_fenics (variable4)*(1 - variable1)
#         # def A44_fenics (variable1 ,variable2, variable3, variable4):
#         #     return p_factor*(1 - variable1)*variable3

#         # Bmat
#         def B11 (var1 ,var2, var3, var4):
#             return rho_l*var2
#         def B12 (var1 ,var2, var3, var4):
#             return rho_l*var1
#         def B13 (var1 ,var2, var3, var4):
#             return 0
#         def B14 (var1 ,var2, var3, var4):
#             return 0

#         # def B11_fenics (variable1 ,variable2, variable3, variable4):
#         #     return rho_l*variable2
#         # def B12_fenics (variable1 ,variable2, variable3, variable4):
#         #     return rho_l*variable1
#         # def B13_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant(0)
#         # def B14_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant(0)

#         #####
#         def B21 (var1 ,var2, var3, var4):
#             return -rho_g (var4)*var3
#         def B22 (var1 ,var2, var3, var4):
#             return 0
#         def B23 (var1 ,var2, var3, var4):
#             return rho_g (var4)*(1 - var1)
#         def B24 (var1 ,var2, var3, var4):
#             return p_factor*(1 - var1)*var3

#         # def B21_fenics (variable1 ,variable2, variable3, variable4):
#         #     return -rho_g_fenics (variable4)*variable3
#         # def B22_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant(0)
#         # def B23_fenics (variable1 ,variable2, variable3, variable4):
#         #     return rho_g_fenics (variable4)*(1 - variable1)
#         # def B24_fenics (variable1 ,variable2, variable3, variable4):
#         #     return p_factor*(1 - variable1)*variable3

#         #####
#         def B31 (var1 ,var2, var3, var4):
#             return rho_l*var2**2 + rho_l*Dc (var1)*var1
#         def B32 (var1 ,var2, var3, var4):
#             return 2*rho_l*var1*var2
#         def B33 (var1 ,var2, var3, var4):
#             return 0
#         def B34 (var1 ,var2, var3, var4):
#             return var1

#         # def B31_fenics (variable1 ,variable2, variable3, variable4):
#         #     return rho_l*variable2**2 + rho_l*Dc_fenics (variable1)*variable1
#         # def B32_fenics (variable1 ,variable2, variable3, variable4):
#         #     return 2*rho_l*variable1*variable2
#         # def B33_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant(0)
#         # def B34_fenics (variable1 ,variable2, variable3, variable4):
#         #     return variable1

#         #####
#         def B41 (var1 ,var2, var3, var4):
#             return -rho_g (var4)*var3**2 + rho_g (var4)*Dc (var1)*(1 - var1)
#         def B42 (var1 ,var2, var3, var4):
#             return 0
#         def B43 (var1 ,var2, var3, var4):
#             return rho_g (var4)*2*(1 - var1)*var3
#         def B44 (var1 ,var2, var3, var4):
#             return p_factor*(1 - var1)*var3**2 + (1 - var1)

#         # def B41_fenics (variable1 ,variable2, variable3, variable4):
#         #     return -rho_g_fenics (variable4)*variable3**2 + rho_g_fenics (variable4)*Dc_fenics (variable1)*(1 - variable1)
#         # def B42_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant(0)
#         # def B43_fenics (variable1 ,variable2, variable3, variable4):
#         #     return rho_g_fenics (variable4)*2*(1 - variable1)*variable3
#         # def B44_fenics (variable1 ,variable2, variable3, variable4):
#         #     return p_factor*(1 - variable1)*variable3**2 + (1 - variable1)
            
#         # Cmat
#         def Cmat1 (var1, var2, var3, var4):
#             return 0
#         def Cmat2 (var1, var2, var3, var4):
#             return 0
#         def Cmat3 (var1, var2, var3, var4):
#             return -rho_l*g*np.sin (beta)*var1 - tau_lw (var1, var2)*P_lw (var1)/A + tau_gl (var1, var2, var3, var4)*P_gl (var1)/A + Fbody*var1
#         def Cmat4 (var1, var2, var3, var4):
#             return -rho_g (var4)*g*np.sin (beta)*(1 - var1) - tau_gw (var1, var3, var4)*P_gw (var1)/A - tau_gl (var1, var2, var3, var4)*P_gl (var1)/A + Fbody*(1 - var1)

#         # def Cmat1_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def Cmat2_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def Cmat3_fenics (variable1 ,variable2, variable3, variable4):
#         #     return -rho_l*g*sin (beta)*variable1 - tau_lw_fenics (variable1, variable2)*P_lw_fenics (variable1)/A + tau_gl_fenics (variable1, variable2, variable3, variable4)*P_gl_fenics (variable1)/A + Fbody*variable1
#         # def Cmat4_fenics (variable1 ,variable2, variable3, variable4):
#         #     return -rho_g_fenics (variable4)*g*sin (beta)*(1 - variable1) - tau_gw_fenics (variable1, variable3, variable4)*P_gw_fenics (variable1)/A - tau_gl_fenics (variable1, variable2, variable3, variable4)*P_gl_fenics (variable1)/A + Fbody*(1 - variable1)
        
#         # # Dmat
#         # def Dmat (var1, var4, Gamma_l, Gamma_g, nu_l, nu_g):
#         #     Dmat = [[rho_l*Gamma_l, 0, 0, 0],
            
#         #             [-rho_g (var4)*Gamma_g, 0, 0, 0],
                    
#         #             [0, var1*nu_l, 0, 0],
                    
#         #             [0, 0, nu_g*(1 - var1), 0]]
#         #     return Dmat

#     # ===============================================================
#     # 2 - QUASILINEAR SYSTEM 
#     # W = (alpha_l, u_l, u_g, p_i)
#     # A = I 
#     # ===============================================================
#     # Matrices
#     elif system == "system_2":
#         # Amat
#         def A11 (var1 ,var2, var3, var4):
#             return 1
#         def A12 (var1 ,var2, var3, var4):
#             return 0
#         def A13 (var1 ,var2, var3, var4):
#             return 0
#         def A14 (var1 ,var2, var3, var4):
#             return 0

#         # def A11_fenics (variable1 ,variable2, variable3, variable4):
#         #     return 1
#         # def A12_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def A13_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def A14_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)

#         #####
#         def A21 (var1 ,var2, var3, var4):
#             return 0
#         def A22 (var1 ,var2, var3, var4):
#             return 1
#         def A23 (var1 ,var2, var3, var4):
#             return 0
#         def A24 (var1 ,var2, var3, var4):
#             return 0

#         # def A21_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def A22_fenics (variable1 ,variable2, variable3, variable4):
#         #     return 1
#         # def A23_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def A24_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)

#         #####
#         def A31 (var1 ,var2, var3, var4):
#             return 0
#         def A32 (var1 ,var2, var3, var4):
#             return 0
#         def A33 (var1 ,var2, var3, var4):
#             return 1
#         def A34 (var1 ,var2, var3, var4):
#             return 0

#         # def A31_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def A32_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def A33_fenics (variable1 ,variable2, variable3, variable4):
#         #     return 1
#         # def A34_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)

#         #####
#         def A41 (var1 ,var2, var3, var4):
#             return 0
#         def A42 (var1 ,var2, var3, var4):
#             return 0
#         def A43 (var1 ,var2, var3, var4):
#             return 0
#         def A44 (var1 ,var2, var3, var4):
#             return 1
        
#         # def A41_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def A42_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def A43_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant (0)
#         # def A44_fenics (variable1 ,variable2, variable3, variable4):
#         #     return 1

#         # Bmat
#         def B11 (var1 ,var2, var3, var4):
#             return var2
#         def B12 (var1 ,var2, var3, var4):
#             return var1
#         def B13 (var1 ,var2, var3, var4):
#             return 0
#         def B14 (var1 ,var2, var3, var4):
#             return 0

#         # def B11_fenics (variable1 ,variable2, variable3, variable4):
#         #     return variable2
#         # def B12_fenics (variable1 ,variable2, variable3, variable4):
#         #     return variable1
#         # def B13_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant(0)
#         # def B14_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant(0)

#         #####
#         def B21 (var1 ,var2, var3, var4):
#             return Dc (var1)
#         def B22 (var1 ,var2, var3, var4):
#             return var2
#         def B23 (var1 ,var2, var3, var4):
#             return 0
#         def B24 (var1 ,var2, var3, var4):
#             return 1/rho_l
        
#         # def B21_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Dc_fenics (variable1)
#         # def B22_fenics (variable1 ,variable2, variable3, variable4):
#         #     return variable2
#         # def B23_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant(0)
#         # def B24_fenics (variable1 ,variable2, variable3, variable4):
#         #     return 1/rho_l

#         #####
#         def B31 (var1 ,var2, var3, var4):
#             return Dc (var1)
#         def B32 (var1 ,var2, var3, var4):
#             return 0
#         def B33 (var1 ,var2, var3, var4):
#             return var3
#         def B34 (var1 ,var2, var3, var4):
#             return 1/rho_g (var4)

#         # def B31_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Dc_fenics (variable1)
#         # def B32_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant(0)
#         # def B33_fenics (variable1 ,variable2, variable3, variable4):
#         #     return variable3
#         # def B34_fenics (variable1 ,variable2, variable3, variable4):
#         #     return 1/rho_g_fenics (variable4)

#         #####
#         def B41 (var1 ,var2, var3, var4):
#             return (-var2 + var3)*var4/(-1 + var1)
#         def B42 (var1 ,var2, var3, var4):
#             return var1*var4/(1 - var1)
#         def B43 (var1 ,var2, var3, var4):
#             return var4
#         def B44 (var1 ,var2, var3, var4):
#             return var3
        
#         # def B41_fenics (variable1 ,variable2, variable3, variable4):
#         #     return (-variable2 + variable3)*variable4/(-1 + variable1)
#         # def B42_fenics (variable1 ,variable2, variable3, variable4):
#         #     return variable1*variable4/(1 - variable1)
#         # def B43_fenics (variable1 ,variable2, variable3, variable4):
#         #     return variable4
#         # def B44_fenics (variable1 ,variable2, variable3, variable4):
#         #     return variable3

#         # Cmat
#         def Cmat1 (var1, var2, var3, var4):
#             return 0
#         def Cmat2 (var1, var2, var3, var4):
#             return  (-np.sin(beta)*g*rho_l*var1 + tau_gl (var1, var2, var3, var4)*P_gl (var1)/A - tau_lw (var1, var2)*P_lw (var1)/A + Fbody*var1)/(rho_l*var1)
#         def Cmat3 (var1, var2, var3, var4):
#             return -np.sin(beta)*g + (tau_gl (var1, var2, var3, var4)*P_gl (var1)/A + tau_gw (var1, var3, var4)*P_gw (var1)/A + Fbody*(-1 + var1))/(rho_g (var4)*(-1 + var1))
#         def Cmat4 (var1, var2, var3, var4):
#             return 0

#         # def Cmat1_fenics (variable1 ,variable2, variable3, variable4):
#         #     return Constant(0)
#         # def Cmat2_fenics (variable1 ,variable2, variable3, variable4):
#         #     return  -sin (beta)*g + (1/A - 1/A + Fbody*variable1)/(rho_l*variable1)
#         #     # return  -sin(beta)*g*rho_l*var1 + (tau_gl_fenics (var1, var2, var3, var4)*P_gl (var1)/A - tau_lw (var1, var2)*P_lw (var1)/A + Fbody*var1)/(rho_l*var1)
#         # def Cmat3_fenics (variable1 ,variable2, variable3, variable4):
#         #     return -sin (beta)*g  + ( Fbody*(-1 + variable1))/(rho_g_fenics (variable4)*(-1 + variable1))
#         #     # return -sin(beta)*g + (tau_gl_fenics (var1, var2, var3, var4)*P_gl (var1)/A + tau_gw (var1, var3, var4)*P_gw (var1)/A + Fbody*(-1 + var1))/(rho_g (var4)*(-1 + var1))
#         # def Cmat4_fenics (var1, var2, var3, var4):
#         #     return Constant(0)

#         # # Dmat
#         # def Dmat (var1, var4, Gamma_l, Gamma_g, nu_l, nu_g):
#         #     Dmat = [[rho_l*Gamma_l, 0, 0, 0],
            
#         #             [-rho_g (var4)*Gamma_g, 0, 0, 0],
                    
#         #             [0, var1*nu_l, 0, 0],
                    
#         #             [0, 0, nu_g*(1 - var1), 0]]
#         #     return Dmat

#     # ===============================================================
#     # MATRICES
#     # ===============================================================
#     # Amat
#     def Amat (var1, var2, var3, var4):
#         Amat = [[A11 (var1 ,var2, var3, var4), A12 (var1 ,var2, var3, var4), A13 (var1 ,var2, var3, var4), A14 (var1 ,var2, var3, var4)], 

#         [A21 (var1 ,var2, var3, var4), A22 (var1 ,var2, var3, var4), A23 (var1 ,var2, var3, var4), A24 (var1 ,var2, var3, var4)], 

#         [A31 (var1 ,var2, var3, var4), A32 (var1 ,var2, var3, var4), A33 (var1 ,var2, var3, var4), A34 (var1 ,var2, var3, var4)], 

#         [A41 (var1 ,var2, var3, var4), A42 (var1 ,var2, var3, var4), A43 (var1 ,var2, var3, var4), A44 (var1 ,var2, var3, var4)]]
#         return Amat

#     # Bmat
#     def Bmat (var1, var2, var3, var4):
#         Bmat = [[B11 (var1 ,var2, var3, var4), B12 (var1 ,var2, var3, var4), B13 (var1 ,var2, var3, var4), B14 (var1 ,var2, var3, var4)], 

#         [B21 (var1 ,var2, var3, var4), B22 (var1 ,var2, var3, var4), B23 (var1 ,var2, var3, var4), B24 (var1 ,var2, var3, var4)], 

#         [B31 (var1 ,var2, var3, var4), B32 (var1 ,var2, var3, var4), B33 (var1 ,var2, var3, var4), B34 (var1 ,var2, var3, var4)], 
        
#         [B41 (var1 ,var2, var3, var4), B42 (var1 ,var2, var3, var4), B43 (var1 ,var2, var3, var4), B44 (var1 ,var2, var3, var4)]]
#         return Bmat

#     # Cmat linearization
#     def Cmat1_var1 (var1):
#         var2 = ref[1]
#         var3 = ref[2]
#         var4 = ref[3]
#         return Cmat1 (var1, var2, var3, var4)
#     def Cmat1_var2 (var2):
#         var1 = ref[0]
#         var3 = ref[2]
#         var4 = ref[3]
#         return Cmat1 (var1, var2, var3, var4)
#     def Cmat1_var3 (var3):
#         var1 = ref[0]
#         var2 = ref[1]
#         var4 = ref[3]
#         return Cmat1 (var1, var2, var3, var4)
#     def Cmat1_var4 (var4):
#         var1 = ref[0]
#         var2 = ref[1]
#         var3 = ref[2]
#         return Cmat1 (var1, var2, var3, var4)

#     def Cmat2_var1 (var1):
#         var2 = ref[1]
#         var3 = ref[2]
#         var4 = ref[3]
#         return Cmat2 (var1, var2, var3, var4)
#     def Cmat2_var2 (var2):
#         var1 = ref[0]
#         var3 = ref[2]
#         var4 = ref[3]
#         return Cmat2 (var1, var2, var3, var4)
#     def Cmat2_var3 (var3):
#         var1 = ref[0]
#         var2 = ref[1]
#         var4 = ref[3]
#         return Cmat2 (var1, var2, var3, var4)
#     def Cmat2_var4 (var4):
#         var1 = ref[0]
#         var2 = ref[1]
#         var3 = ref[2]
#         return Cmat2 (var1, var2, var3, var4)

#     def Cmat3_var1 (var1):
#         var2 = ref[1]
#         var3 = ref[2]
#         var4 = ref[3]
#         return Cmat3 (var1, var2, var3, var4)
#     def Cmat3_var2 (var2):
#         var1 = ref[0]
#         var3 = ref[2]
#         var4 = ref[3]
#         return Cmat3 (var1, var2, var3, var4)
#     def Cmat3_var3 (var3):
#         var1 = ref[0]
#         var2 = ref[1]
#         var4 = ref[3]
#         return Cmat3 (var1, var2, var3, var4)
#     def Cmat3_var4 (var4):
#         var1 = ref[0]
#         var2 = ref[1]
#         var3 = ref[2]
#         return Cmat3 (var1, var2, var3, var4)

#     def Cmat4_var1 (var1):
#         var2 = ref[1]
#         var3 = ref[2]
#         var4 = ref[3]
#         return Cmat4(var1, var2, var3, var4)
#     def Cmat4_var2 (var2):
#         var1 = ref[0]
#         var3 = ref[2]
#         var4 = ref[3]
#         return Cmat4(var1, var2, var3, var4)
#     def Cmat4_var3 (var3):
#         var1 = ref[0]
#         var2 = ref[1]
#         var4 = ref[3]
#         return Cmat4(var1, var2, var3, var4)
#     def Cmat4_var4 (var4):
#         var1 = ref[0]
#         var2 = ref[1]
#         var3 = ref[2]
#         return Cmat4(var1, var2, var3, var4)

#     # Cmat_lin
#     def Cmat_lin (var1, var2, var3, var4):
#         Cmat_lin = [[gradient (Cmat1_var1, 1), gradient (Cmat1_var2, 2), gradient (Cmat1_var3, 3), gradient (Cmat1_var4, 4)], 
#                     [gradient (Cmat2_var1, 1), gradient (Cmat2_var2, 2), gradient (Cmat2_var3, 3), gradient (Cmat2_var4, 4)], 
#                     [gradient (Cmat3_var1, 1), gradient (Cmat3_var2, 2), gradient (Cmat3_var3, 3), gradient (Cmat3_var4, 4)], 
#                     [gradient (Cmat4_var1, 1), gradient (Cmat4_var2, 2), gradient (Cmat4_var3, 3), gradient (Cmat4_var4, 4)]]
#         return Cmat_lin

#     # Matrices
#     Aeval = np.asarray (Amat (var1, var2, var3, var4))
#     Beval = np.asarray (Bmat (var1, var2, var3, var4))
#     Ceval = np.asarray (Cmat_lin (var1, var2, var3, var4))

#     return Aeval, Beval, Ceval

# # # FUNCTION: 
# # Aeval, Beval, Ceval = linear_matrices_function (var1, var2, var3, var4, beta, D, rho_l, p_factor, mu_l, mu_g, dirichlet_type)

# %% [markdown]
# ## 5. Linear matrices
# Conserved variables

# %%
# # ===============================================================
# # LINEAR MATRICES
# # ===============================================================
# def linear_matrices_function_conserved (var1, var2, var3, var4, beta, D, system, rho_l, p_factor, mu_l, mu_g, dirichlet_type):
#     # Matrices
#     if system == "system_3":
#         # Define body force
#         if dirichlet_type == "nonperiodic": 
#             Fbody = 0
#         elif dirichlet_type == "periodic": 
#             Fbody = 74.225
#         # Variables 
#         def var1_ (var1):
#             return var1/rho_l
#         def var2_ (var1, var3):
#             return var3/var1
#         def var3_ (var2, var4):
#             return var4/var2
#         def var4_ (var1, var2):
#             return var2/((1 - var1/rho_l)*p_factor)

#         # stratification angle
#         def gamma (var1):
#             return DOLFIN_PI*(var1_ (var1) + DOLFIN_EPS) + pow ((3.*DOLFIN_PI/2.), (1./3.))*(1 - 2*(var1_ (var1) + DOLFIN_EPS) + pow (abs (var1_ (var1) + DOLFIN_EPS), (1./3.)) - pow (abs(1 - (var1_ (var1) + DOLFIN_EPS)), (1/3))) - (1/200)*(1 - (var1_ (var1) + DOLFIN_EPS))*(var1_ (var1) + DOLFIN_EPS)*(1 - 2*(var1_ (var1) + DOLFIN_EPS))*(1 + 4*((1 - (var1_ (var1) + DOLFIN_EPS))**2 + (var1_ (var1) +  + DOLFIN_EPS)**2))
#         # Critic diameter
#         def Dc (var1):
#             return g*np.cos (beta)*DOLFIN_PI*D/(4*np.sin (gamma (var1)))
#         # Area
#         A = DOLFIN_PI*D**2./4.0# mˆ2, total area
#         # liquid sectional area
#         def A_l (var1):
#             return A*var1_ (var1)
#         # gas sectional area
#         def A_g (var1):
#             return A*(1 - var1_ (var1))
#         # liquid wetted perimeter
#         def P_lw (var1):
#             return D*gamma (var1)
#         # gas wetted perimeter
#         def P_gw (var1):
#             return D*(DOLFIN_PI - gamma (var1))
#         # interface wetted perimeter
#         def P_gl (var1):
#             return D*np.sin (gamma (var1))
#         # liquid hydraulic diameter 
#         def Dh_l (var1):
#             return 4.*A_l (var1)/P_lw (var1)
#         # gas hydraulic diameter 
#         def Dh_g (var1):
#             return 4.*A_g (var1)/(P_gw (var1) + P_gl (var1))
#         # Gas density
#         def rho_g (var1, var2):
#             return p_factor*var4_ (var1, var2) + DOLFIN_EPS
#         # liquid Reynolds number
#         def Re_l (var1, var3):
#             return rho_l*var2_(var1, var3)*Dh_l (var1)/mu_l
#         # gas Reynolds number
#         def Re_g (var1, var2, var4):
#             return rho_g (var1, var2)*var3_ (var2, var4)*Dh_g (var1)/mu_g
#         # interface hydraulic diameter and Reynolds number
#         def Dh_gl (var1):
#             return 4.*A_g (var1)/(P_gw (var1) + P_gl (var1))
#     #     def Re_gl (var1, var2, var3, var4):
#     #         return rho_g (var4)*abs (var3 - var2)*Dh_gl (var1)/mu_g
#         # Friction factor liquid-wall
#         def f_lw (var1, var3):
#             return 0.046*abs (Re_l (var1, var3))**(-0.2)
#         # Friction factor gas-wall
#         def f_gw (var1, var2, var4):
#             return 0.046*abs (Re_g (var1, var2, var4))**(-0.2)
#         # interfacial friction
#         def f_gl (var1, var2, var4):
#             return max (f_gw (var1, var2, var4), 0.014)
#         # Shear stress liquid-wall
#         def tau_lw (var1, var3):
#             return 1/2*f_lw (var1, var3)*rho_l*var2_ (var1, var3)*abs (var2_ (var1, var3))
#         # Shear stress gas-wall
#         def tau_gw (var1, var2, var4):
#             return 1/2*f_gw (var1, var2, var4)*rho_g (var1, var2)*var3_ (var2, var4)*abs (var3_ (var2, var4))
#         # interface shear stress
#         def tau_gl (var1, var2, var3, var4):
#             return 1/2*f_gl(var1, var2, var4)*rho_g (var1, var2)*(var3_ (var2, var4) - var2_ (var1, var3))*abs (var3_ (var2, var4) - var2_ (var1, var3))

#         # ===============================================================
#         # 3 - QUASILINEAR SYSTEM 
#         # W = (alpha_l*rho_l, alpha_g*rho_g, alpha_l*rho_l*u_l, alpha_g*rho_g*u_g)
#         # A = I 
#         # ===============================================================
#         # Amat
#         def A11 (var1, var2, var3, var4):
#             return 1
#         def A12 (var1, var2, var3, var4):
#             return 0
#         def A13 (var1, var2, var3, var4):
#             return 0
#         def A14 (var1, var2, var3, var4):
#             return 0

#         #####

#         def A21 (var1, var2, var3, var4):
#             return 0
#         def A22 (var1, var2, var3, var4):
#             return 1
#         def A23 (var1, var2, var3, var4):
#             return 0
#         def A24 (var1, var2, var3, var4):
#             return 0

#         #####

#         def A31 (var1, var2, var3, var4):
#             return 0
#         def A32 (var1, var2, var3, var4):
#             return 0
#         def A33 (var1, var2, var3, var4):
#             return 1
#         def A34 (var1, var2, var3, var4):
#             return 0

#         #####

#         def A41 (var1, var2, var3, var4):
#             return 0
#         def A42 (var1, var2, var3, var4):
#             return 0
#         def A43 (var1, var2, var3, var4):
#             return 0
#         def A44 (var1, var2, var3, var4):
#             return 1

#         # Bmat
#         def B11 (var1, var2, var3, var4):
#             return 0
#         def B12 (var1, var2, var3, var4):
#             return 0
#         def B13 (var1, var2, var3, var4):
#             return 1
#         def B14 (var1, var2, var3, var4):
#             return 0

#         #####

#         def B21 (var1, var2, var3, var4):
#             return 0
#         def B22 (var1, var2, var3, var4):
#             return 0
#         def B23 (var1, var2, var3, var4):
#             return 0
#         def B24 (var1, var2, var3, var4):
#             return 1

#         #####

#         def B31 (var1, var2, var3, var4):
#             return Dc (var1)/rho_l + (var1*var2)/(p_factor*(rho_l - var1)**2) - (var3/var1)**2
#         def B32 (var1, var2, var3, var4):
#             return var1/(rho_l*p_factor - p_factor*var1)
#         def B33 (var1, var2, var3, var4):
#             return 2*var3/var1
#         def B34 (var1, var2, var3, var4):
#             return 0

#         #####

#         def B41 (var1, var2, var3, var4):
#             return (rho_l + Dc (var1)*p_factor*rho_l - Dc (var1)*p_factor*var1)*var2/(p_factor*rho_l*(rho_l - var1))
#         def B42 (var1, var2, var3, var4):
#             return 1/p_factor - (var4/var2)**2
#         def B43 (var1, var2, var3, var4):
#             return 0
#         def B44 (var1, var2, var3, var4):
#             return 2*var4/var2

#         # Cmat
#         def Cmat1 (var1, var2, var3, var4):
#             return 0
#         def Cmat2 (var1, var2, var3, var4):
#             return 0
#         def Cmat3 (var1, var2, var3, var4):
#             return tau_gl (var1, var2, var3, var4)*P_gl (var1)/A - tau_lw (var1, var3)*P_lw (var1)/A - np.sin (beta)*g*var1 + Fbody*var1/rho_l
#         def Cmat4 (var1, var2, var3, var4):
#             return Fbody - tau_gl (var1, var2, var3, var4)*P_gl (var1)/A - tau_gw (var1, var2, var4)*P_gw (var1)/A - Fbody*var1/rho_l - np.sin (beta)*g*var2
            
#     #     # # # Dmat
#     #     # # def Dmat (var1, var4, Gamma_l, Gamma_g, nu_l, nu_g):
#     #     # #     Dmat = [[rho_l*Gamma_l, 0, 0, 0],
            
#     #     # #             [-rho_g (var4)*Gamma_g, 0, 0, 0],
                    
#     #     # #             [0, var1*nu_l, 0, 0],
                    
#     #     # #             [0, 0, nu_g*(1 - var1), 0]]
#     #     # #     return Dmat


#     # ===============================================================
#     # MATRICES
#     # ===============================================================
#     # Amat
#     def Amat (var1, var2, var3, var4):
#         Amat = [[A11 (var1 ,var2, var3, var4), A12 (var1 ,var2, var3, var4), A13 (var1 ,var2, var3, var4), A14 (var1 ,var2, var3, var4)], 

#         [A21 (var1 ,var2, var3, var4), A22 (var1 ,var2, var3, var4), A23 (var1 ,var2, var3, var4), A24 (var1 ,var2, var3, var4)], 

#         [A31 (var1 ,var2, var3, var4), A32 (var1 ,var2, var3, var4), A33 (var1 ,var2, var3, var4), A34 (var1 ,var2, var3, var4)], 

#         [A41 (var1 ,var2, var3, var4), A42 (var1 ,var2, var3, var4), A43 (var1 ,var2, var3, var4), A44 (var1 ,var2, var3, var4)]]
#         return Amat

#     # Bmat
#     def Bmat (var1, var2, var3, var4):
#         Bmat = [[B11 (var1 ,var2, var3, var4), B12 (var1 ,var2, var3, var4), B13 (var1 ,var2, var3, var4), B14 (var1 ,var2, var3, var4)], 

#         [B21 (var1 ,var2, var3, var4), B22 (var1 ,var2, var3, var4), B23 (var1 ,var2, var3, var4), B24 (var1 ,var2, var3, var4)], 

#         [B31 (var1 ,var2, var3, var4), B32 (var1 ,var2, var3, var4), B33 (var1 ,var2, var3, var4), B34 (var1 ,var2, var3, var4)], 
        
#         [B41 (var1 ,var2, var3, var4), B42 (var1 ,var2, var3, var4), B43 (var1 ,var2, var3, var4), B44 (var1 ,var2, var3, var4)]]
#         return Bmat

#     # Cmat linearization
#     def Cmat1_var1 (var1):
#         var2 = ref[1]
#         var3 = ref[2]
#         var4 = ref[3]
#         return Cmat1 (var1, var2, var3, var4)
#     def Cmat1_var2 (var2):
#         var1 = ref[0]
#         var3 = ref[2]
#         var4 = ref[3]
#         return Cmat1 (var1, var2, var3, var4)
#     def Cmat1_var3 (var3):
#         var1 = ref[0]
#         var2 = ref[1]
#         var4 = ref[3]
#         return Cmat1 (var1, var2, var3, var4)
#     def Cmat1_var4 (var4):
#         var1 = ref[0]
#         var2 = ref[1]
#         var3 = ref[2]
#         return Cmat1 (var1, var2, var3, var4)

#     def Cmat2_var1 (var1):
#         var2 = ref[1]
#         var3 = ref[2]
#         var4 = ref[3]
#         return Cmat2 (var1, var2, var3, var4)
#     def Cmat2_var2 (var2):
#         var1 = ref[0]
#         var3 = ref[2]
#         var4 = ref[3]
#         return Cmat2 (var1, var2, var3, var4)
#     def Cmat2_var3 (var3):
#         var1 = ref[0]
#         var2 = ref[1]
#         var4 = ref[3]
#         return Cmat2 (var1, var2, var3, var4)
#     def Cmat2_var4 (var4):
#         var1 = ref[0]
#         var2 = ref[1]
#         var3 = ref[2]
#         return Cmat2 (var1, var2, var3, var4)

#     def Cmat3_var1 (var1):
#         var2 = ref[1]
#         var3 = ref[2]
#         var4 = ref[3]
#         return Cmat3 (var1, var2, var3, var4)
#     def Cmat3_var2 (var2):
#         var1 = ref[0]
#         var3 = ref[2]
#         var4 = ref[3]
#         return Cmat3 (var1, var2, var3, var4)
#     def Cmat3_var3 (var3):
#         var1 = ref[0]
#         var2 = ref[1]
#         var4 = ref[3]
#         return Cmat3 (var1, var2, var3, var4)
#     def Cmat3_var4 (var4):
#         var1 = ref[0]
#         var2 = ref[1]
#         var3 = ref[2]
#         return Cmat3 (var1, var2, var3, var4)

#     def Cmat4_var1 (var1):
#         var2 = ref[1]
#         var3 = ref[2]
#         var4 = ref[3]
#         return Cmat4(var1, var2, var3, var4)
#     def Cmat4_var2 (var2):
#         var1 = ref[0]
#         var3 = ref[2]
#         var4 = ref[3]
#         return Cmat4(var1, var2, var3, var4)
#     def Cmat4_var3 (var3):
#         var1 = ref[0]
#         var2 = ref[1]
#         var4 = ref[3]
#         return Cmat4(var1, var2, var3, var4)
#     def Cmat4_var4 (var4):
#         var1 = ref[0]
#         var2 = ref[1]
#         var3 = ref[2]
#         return Cmat4(var1, var2, var3, var4)

#     # Cmat_lin
#     def Cmat_lin (var1, var2, var3, var4):
#         Cmat_lin = [[gradient (Cmat1_var1, 1), gradient (Cmat1_var2, 2), gradient (Cmat1_var3, 3), gradient (Cmat1_var4, 4)], 
#                     [gradient (Cmat2_var1, 1), gradient (Cmat2_var2, 2), gradient (Cmat2_var3, 3), gradient (Cmat2_var4, 4)], 
#                     [gradient (Cmat3_var1, 1), gradient (Cmat3_var2, 2), gradient (Cmat3_var3, 3), gradient (Cmat3_var4, 4)], 
#                     [gradient (Cmat4_var1, 1), gradient (Cmat4_var2, 2), gradient (Cmat4_var3, 3), gradient (Cmat4_var4, 4)]]
#         return Cmat_lin

#     # Matrices
#     Aeval = np.asarray (Amat (var1, var2, var3, var4))
#     Beval = np.asarray (Bmat (var1, var2, var3, var4))
#     Ceval = np.asarray (Cmat_lin (var1, var2, var3, var4))

#     return Aeval, Beval, Ceval

# # # FUNCTION: 
# # Aeval, Beval, Ceval = linear_matrices_function_conserved (var1, var2, var3, var4, beta, D, rho_l, p_factor, mu_l, mu_g, dirichlet_type)

# %% [markdown]
# # For 8_code_stability

# %%
# VARIABLES
# var1: liquid volume fraction (alpha_l)
# var2: liquid velocity (u_l)
# var3: gas velocity (u_g)
# var4: interfacial pressure (p_i)

# FUNCTIONS
# stratification angle
def gamma (var1):
    return pi*var1 + pow ((3.*pi/2.), (1./3.))*(1 - 2*var1 + pow (abs (var1), (1./3.)) - pow (abs(1 - var1), (1/3))) - (1/200)*(1-var1)*var1*(1 - 2*var1)*(1+4*((1-var1)**2+(var1)**2))

#Gas density
def rho_g (var4):
    return p_factor*var4

# liquid phase velocity
def var2 (var1):
    return j_l/(var1)

# gas phase velocity
def var3 (var1):
    return j_g/(1 - var1)

# liquid sectional area
def A_l (var1):
    return A*var1

# gas sectional area
def A_g (var1):
    return A*(1 - var1)

# liquid wetted perimeter
def P_lw (var1):
    return D*gamma (var1)

# gas wetted perimeter
def P_gw (var1):
    return D*(pi - gamma (var1))

# interface wetted perimeter
def P_gl (var1):
    return D*np.sin (gamma (var1))

def P_gl_fenics (var1):
    return D*sin (gamma (var1))

# liquid hydraulic diameter 
def Dh_l (var1):
    return 4.*A_l (var1)/P_lw (var1)

# gas hydraulic diameter 
def Dh_g (var1):
    return 4.*A_g (var1)/(P_gw (var1) + P_gl (var1))

def Dh_g_fenics (var1):
    return 4.*A_g (var1)/(P_gw (var1) + P_gl_fenics (var1))

# interface hydraulic diameter 
def Dh_gl (var1):
    return 4.*A_g (var1)/(P_gw (var1) + P_gl (var1))

def Dh_gl_fenics (var1):
    return 4.*A_g (var1)/(P_gw (var1) + P_gl_fenics (var1))

# critic diameter
def Dc (var1):
    return g*np.cos (beta)*pi*D/(4*np.sin (gamma (var1)))

def Dc_fenics (var1):
    return g*cos (beta)*pi*D/(4*sin (gamma (var1)))

# liquid Reynolds number
def Re_l (var1, var2):
    return rho_l*var2*Dh_l (var1)/mu_l

# def Re_l (var1, var2):
#     return D*j_l*rho_l/mu_l
# def Re_l (var1, var2):  #ppppp
#     return D*var1*var2*rho_l/mu_l

# gas Reynolds number
def Re_g (var1, var3, var4):
    return rho_g (var4)*var3*Dh_g (var1)/mu_g

def Re_g_fenics (var1, var3, var4):
    return rho_g (var4)*var3*Dh_g_fenics (var1)/mu_g

# interface Reynolds number
def Re_gl (var1, var2, var3, var4):
    return rho_g (var4)*abs(var3 - var2)*Dh_gl (var1)/mu_g

def Re_gl_fenics (var1, var2, var3, var4):
    return rho_g (var4)*abs(var3 - var2)*Dh_gl_fenics (var1)/mu_g

# liquid friction factor
# def f_lw (var1, var2):
#     Af_lw = pow (2.457*np.log (pow (pow (abs (7/Re_l (var1, var2)), 0.9) + 0.27*roughness/Dh_l (var1), -1)), 16)
#     Bf_lw = pow (abs (37530/Re_l (var1, var2)), 16)
#     return 2*pow (pow (abs (8/Re_l (var1, var2)), 12) + pow (abs (Af_lw + Bf_lw), - 1.5), 1/12)

def f_lw_fenics (var1, var2):
    Af_lw = pow (2.457*ln (pow (pow (abs (7/Re_l (var1, var2)), 0.9) + 0.27*roughness/Dh_l (var1), -1)), 16)
    Bf_lw = pow (abs (37530/Re_l (var1, var2)), 16)
    return 2*pow (pow (abs (8/Re_l (var1, var2)), 12) + pow (abs (Af_lw + Bf_lw), - 1.5), 1/12)

def f_lw (var1, var2):
    return 0.046*abs(Re_l (var1, var2))**(-0.2)

# def f_lw (var1, var2):
#     return 0.0262*pow (abs(var1*Re_l (var1, var2)), -0.139)

def f_lw_laminar (var1, var2):
    return 24/Re_l (var1, var2)

# gas friction factor
# def f_gw (var1, var3, var4):
#     Af_gw = pow (2.457*np.log (pow (pow (abs (7/Re_g (var1, var3, var4)), 0.9) + 0.27*roughness/Dh_g (var1), - 1)), 16)
#     Bf_gw = pow (abs (37530/Re_g (var1, var3, var4)), 16)
#     return 2*pow (pow (abs (8/Re_g (var1, var3, var4)), 12) + pow (abs (Af_gw + Bf_gw), - 1.5), 1/12)

def f_gw_fenics (var1, var3, var4):
    Af_gw = pow (2.457*ln (pow (pow (abs (7/Re_g_fenics (var1, var3, var4)), 0.9) + 0.27*roughness/Dh_g_fenics (var1), - 1)), 16)
    Bf_gw = pow (abs (37530/Re_g_fenics (var1, var3, var4)), 16)
    return 2*pow (pow (abs (8/Re_g_fenics (var1, var3, var4)), 12) + pow (abs (Af_gw + Bf_gw), - 1.5), 1/12)

def f_gw (var1, var3, var4):
    return 0.046*abs(Re_g (var1, var3, var4))**(-0.2)

# def f_gw_fenics (var1, var3, var4):
#     return 0.046*pow (abs(Re_g_fenics (var1, var3, var4)), -0.2)

def f_gw_laminar (var1, var3, var4):
    return 16 / Re_g (var1, var3, var4)

# interfacial friction
def f_gl (var1, var2, var3, var4):
    return max (f_gw (var1, var3, var4), 0.014)

# def f_gl (var1, var2, var3, var4):
#     return 0.046*pow (abs(Re_gl (var1, var2, var3, var4)), -0.2)
def f_gl_laminar (var1, var2, var3, var4):
    return 16 / Re_gl (var1, var2, var3, var4)
# def f_gl_fenics (var1, var2, var3, var4):
#     return 0.046*pow (abs(Re_gl_fenics (var1, var2, var3, var4)), -0.2)
def f_gl_fenics (var1, var2, var3, var4):
    return max (f_gw_fenics (var1, var3, var4), 0.014)
# liquid shear stress
def tau_lw (var1, var2):
    return 1/2*f_lw (var1, var2)*rho_l*var2*abs (var2)
# gas shear stress
def tau_gw (var1, var3, var4):
    return 1/2*f_gw (var1, var3, var4)*rho_g (var4)*var3*abs (var3)
def tau_gw_fenics (var1, var3, var4):
    return 1/2*f_gw_fenics (var1, var3, var4)*rho_g (var4)*var3*abs (var3)
# interface shear stress l
def tau_gl (var1, var2, var3, var4):
    return 1/2*f_gl(var1, var2, var3, var4)*rho_g (var4)*(var3 - var2)*abs (var3 - var2)

def tau_gl_fenics (var1, var2, var3, var4):
    return 1/2*f_gl_fenics (var1, var2, var3, var4)*rho_g (var4)*(var3 - var2)*abs (var3 - var2)
# steady state momentum equation for horizontal steady state (characteristics and fourier). var4 is known, compute var1
def equilibrium1 (var1): 
    return (rho_g (var4) - rho_l)*g*np.sin (beta) - tau_lw (var1, var2 (var1))*P_lw (var1)/A_l (var1) + tau_gw (var1, var3 (var1), var4)*P_gw (var1)/A_g (var1) + tau_gl (var1, var2 (var1), var3 (var1), var4)*P_gl (var1)*(1/A_l (var1) + 1/A_g (var1))
# liquid phase velocity
def var2b (j_l):
    return j_l/(var1)
# stady state momentum equation for horizontal steady state (characteristics and fourier). var4 is known, compute j_l
def equilibrium2 (j_l):  
    return (rho_g (var4) - rho_l)*g*np.sin (beta) - tau_lw (var1, var2b (j_l))*P_lw (var1)/A_l (var1) + tau_gw (var1, var3 (var1), var4)*P_gw (var1)/A_g (var1) + tau_gl (var1, var2b (j_l), var3 (var1), var4)*P_gl (var1)*(1/A_l (var1) + 1/A_g (var1))

# Amat
def Amat (var1, var2, var3, var4):
    Amat = [[A11 (var1 ,var2, var3, var4), A12 (var1 ,var2, var3, var4), A13 (var1 ,var2, var3, var4), A14 (var1 ,var2, var3, var4)], 

    [A21 (var1 ,var2, var3, var4), A22 (var1 ,var2, var3, var4), A23 (var1 ,var2, var3, var4), A24 (var1 ,var2, var3, var4)], 

    [A31 (var1 ,var2, var3, var4), A32 (var1 ,var2, var3, var4), A33 (var1 ,var2, var3, var4), A34 (var1 ,var2, var3, var4)], 

    [A41 (var1 ,var2, var3, var4), A42 (var1 ,var2, var3, var4), A43 (var1 ,var2, var3, var4), A44 (var1 ,var2, var3, var4)]]
    return Amat

# Bmat
def Bmat (var1, var2, var3, var4):
    Bmat = [[B11 (var1 ,var2, var3, var4), B12 (var1 ,var2, var3, var4), B13 (var1 ,var2, var3, var4), B14 (var1 ,var2, var3, var4)], 

    [B21 (var1 ,var2, var3, var4), B22 (var1 ,var2, var3, var4), B23 (var1 ,var2, var3, var4), B24 (var1 ,var2, var3, var4)], 

    [B31 (var1 ,var2, var3, var4), B32 (var1 ,var2, var3, var4), B33 (var1 ,var2, var3, var4), B34 (var1 ,var2, var3, var4)], 
    
    [B41 (var1 ,var2, var3, var4), B42 (var1 ,var2, var3, var4), B43 (var1 ,var2, var3, var4), B44 (var1 ,var2, var3, var4)]]
    return Bmat

# Cmat linearization
def Cmat1_var1 (var1):
    var2 = ref[1]
    var3 = ref[2]
    var4 = ref[3]
    return Cmat1 (var1, var2, var3, var4)
def Cmat1_var2 (var2):
    var1 = ref[0]
    var3 = ref[2]
    var4 = ref[3]
    return Cmat1 (var1, var2, var3, var4)
def Cmat1_var3 (var3):
    var1 = ref[0]
    var2 = ref[1]
    var4 = ref[3]
    return Cmat1 (var1, var2, var3, var4)
def Cmat1_var4 (var4):
    var1 = ref[0]
    var2 = ref[1]
    var3 = ref[2]
    return Cmat1 (var1, var2, var3, var4)

def Cmat2_var1 (var1):
    var2 = ref[1]
    var3 = ref[2]
    var4 = ref[3]
    return Cmat2 (var1, var2, var3, var4)
def Cmat2_var2 (var2):
    var1 = ref[0]
    var3 = ref[2]
    var4 = ref[3]
    return Cmat2 (var1, var2, var3, var4)
def Cmat2_var3 (var3):
    var1 = ref[0]
    var2 = ref[1]
    var4 = ref[3]
    return Cmat2 (var1, var2, var3, var4)
def Cmat2_var4 (var4):
    var1 = ref[0]
    var2 = ref[1]
    var3 = ref[2]
    return Cmat2 (var1, var2, var3, var4)

def Cmat3_var1 (var1):
    var2 = ref[1]
    var3 = ref[2]
    var4 = ref[3]
    return Cmat3 (var1, var2, var3, var4)
def Cmat3_var2 (var2):
    var1 = ref[0]
    var3 = ref[2]
    var4 = ref[3]
    return Cmat3 (var1, var2, var3, var4)
def Cmat3_var3 (var3):
    var1 = ref[0]
    var2 = ref[1]
    var4 = ref[3]
    return Cmat3 (var1, var2, var3, var4)
def Cmat3_var4 (var4):
    var1 = ref[0]
    var2 = ref[1]
    var3 = ref[2]
    return Cmat3 (var1, var2, var3, var4)

def Cmat4_var1 (var1):
    var2 = ref[1]
    var3 = ref[2]
    var4 = ref[3]
    return Cmat4(var1, var2, var3, var4)
def Cmat4_var2 (var2):
    var1 = ref[0]
    var3 = ref[2]
    var4 = ref[3]
    return Cmat4(var1, var2, var3, var4)
def Cmat4_var3 (var3):
    var1 = ref[0]
    var2 = ref[1]
    var4 = ref[3]
    return Cmat4(var1, var2, var3, var4)
def Cmat4_var4 (var4):
    var1 = ref[0]
    var2 = ref[1]
    var3 = ref[2]
    return Cmat4(var1, var2, var3, var4)

# Cmat_lin
def Cmat_lin (var1, var2, var3, var4):
    Cmat_lin = [[gradient (Cmat1_var1, 1), gradient (Cmat1_var2, 2), gradient (Cmat1_var3, 3), gradient (Cmat1_var4, 4)], 
                [gradient (Cmat2_var1, 1), gradient (Cmat2_var2, 2), gradient (Cmat2_var3, 3), gradient (Cmat2_var4, 4)], 
                [gradient (Cmat3_var1, 1), gradient (Cmat3_var2, 2), gradient (Cmat3_var3, 3), gradient (Cmat3_var4, 4)], 
                [gradient (Cmat4_var1, 1), gradient (Cmat4_var2, 2), gradient (Cmat4_var3, 3), gradient (Cmat4_var4, 4)]]
    return Cmat_lin

# ===============================================================
# 1 - QUASILINEAR SYSTEM 
# W = (alpha_l, u_l, u_g, p_i)
# A != I
# ===============================================================
# Matrices
if system == "system_1":
    # Amat
    def A11 (var1 ,var2, var3, var4):
        return rho_l
    def A12 (var1 ,var2, var3, var4):
        return 0
    def A13 (var1 ,var2, var3, var4):
        return 0
    def A14 (var1 ,var2, var3, var4):
        return 0

    def A21 (var1 ,var2, var3, var4):
        return -rho_g (var4)
    def A22 (var1 ,var2, var3, var4):
        return 0
    def A23 (var1 ,var2, var3, var4):
        return 0
    def A24 (var1 ,var2, var3, var4):
        return p_factor*(1 - var1)

    def A31 (var1 ,var2, var3, var4):
        return rho_l*var2
    def A32 (var1 ,var2, var3, var4):
        return rho_l*var1
    def A33 (var1 ,var2, var3, var4):
        return 0
    def A34 (var1 ,var2, var3, var4):
        return 0

    def A41 (var1 ,var2, var3, var4):
        return -rho_g (var4)*var3
    def A42 (var1 ,var2, var3, var4):
        return 0
    def A43 (var1 ,var2, var3, var4):
        return rho_g (var4)*(1 - var1)
    def A44 (var1 ,var2, var3, var4):
        return p_factor*(1 - var1)*var3

    # Bmat
    def B11 (var1 ,var2, var3, var4):
        return rho_l*var2
    def B12 (var1 ,var2, var3, var4):
        return rho_l*var1
    def B13 (var1 ,var2, var3, var4):
        return 0
    def B14 (var1 ,var2, var3, var4):
        return 0

    def B21 (var1 ,var2, var3, var4):
        return -rho_g (var4)*var3
    def B22 (var1 ,var2, var3, var4):
        return 0
    def B23 (var1 ,var2, var3, var4):
        return rho_g (var4)*(1 - var1)
    def B24 (var1 ,var2, var3, var4):
        return p_factor*(1 - var1)*var3

    def B31 (var1 ,var2, var3, var4):
        return rho_l*var2**2 + rho_l*Dc (var1)*var1
    def B32 (var1 ,var2, var3, var4):
        return 2*rho_l*var1*var2
    def B33 (var1 ,var2, var3, var4):
        return 0
    def B34 (var1 ,var2, var3, var4):
        return var1

    def B41 (var1 ,var2, var3, var4):
        return -rho_g (var4)*var3**2 + rho_g (var4)*Dc (var1)*(1 - var1)
    def B42 (var1 ,var2, var3, var4):
        return 0
    def B43 (var1 ,var2, var3, var4):
        return rho_g (var4)*2*(1 - var1)*var3
    def B44 (var1 ,var2, var3, var4):
        return p_factor*(1 - var1)*var3**2 + (1 - var1)

    # Cmat
    def Cmat1 (var1, var2, var3, var4):
        return 0
    def Cmat2 (var1, var2, var3, var4):
        return 0
    def Cmat3 (var1, var2, var3, var4):
        return -rho_l*g*np.sin (beta)*var1 - tau_lw (var1, var2)*P_lw (var1)/A + tau_gl (var1, var2, var3, var4)*P_gl (var1)/A + Fbody*var1
    def Cmat4 (var1, var2, var3, var4):
        return -rho_g (var4)*g*np.sin (beta)*(1 - var1) - tau_gw (var1, var3, var4)*P_gw (var1)/A - tau_gl (var1, var2, var3, var4)*P_gl (var1)/A + Fbody*(1 - var1)

    # Dmat
    def Dmat (var1, var4, Gamma_l, Gamma_g, nu_l, nu_g):
        Dmat = [[rho_l*Gamma_l, 0, 0, 0],
        
                [-rho_g (var4)*Gamma_g, 0, 0, 0],
                
                [0, var1*nu_l, 0, 0],
                
                [0, 0, nu_g*(1 - var1), 0]]
        return Dmat

# ===============================================================
# 2 - QUASILINEAR SYSTEM 
# W = (alpha_l, u_l, u_g, p_i)
# A = I 
# ===============================================================
# Matrices
elif system == "system_2":
    # Amat
    def A11 (var1 ,var2, var3, var4):
        return 1
    def A12 (var1 ,var2, var3, var4):
        return 0
    def A13 (var1 ,var2, var3, var4):
        return 0
    def A14 (var1 ,var2, var3, var4):
        return 0

    def A21 (var1 ,var2, var3, var4):
        return 0
    def A22 (var1 ,var2, var3, var4):
        return 1
    def A23 (var1 ,var2, var3, var4):
        return 0
    def A24 (var1 ,var2, var3, var4):
        return 0

    def A31 (var1 ,var2, var3, var4):
        return 0
    def A32 (var1 ,var2, var3, var4):
        return 0
    def A33 (var1 ,var2, var3, var4):
        return 1
    def A34 (var1 ,var2, var3, var4):
        return 0

    def A41 (var1 ,var2, var3, var4):
        return 0
    def A42 (var1 ,var2, var3, var4):
        return 0
    def A43 (var1 ,var2, var3, var4):
        return 0
    def A44 (var1 ,var2, var3, var4):
        return 1

    # Bmat
    def B11 (var1 ,var2, var3, var4):
        return var2
    def B12 (var1 ,var2, var3, var4):
        return var1
    def B13 (var1 ,var2, var3, var4):
        return 0
    def B14 (var1 ,var2, var3, var4):
        return 0

    def B21 (var1 ,var2, var3, var4):
        return Dc (var1)
    def B22 (var1 ,var2, var3, var4):
        return var2
    def B23 (var1 ,var2, var3, var4):
        return 0
    def B24 (var1 ,var2, var3, var4):
        return 1/(rho_l)

    def B31 (var1 ,var2, var3, var4):
        return Dc (var1)
    def B32 (var1 ,var2, var3, var4):
        return 0
    def B33 (var1 ,var2, var3, var4):
        return var3
    def B34 (var1 ,var2, var3, var4):
        return 1/rho_g (var4)

    def B41 (var1 ,var2, var3, var4):
        return (-var2 + var3)*var4/(-1 + var1)
    def B42 (var1 ,var2, var3, var4):
        return var1*var4/(1 - var1)
    def B43 (var1 ,var2, var3, var4):
        return var4
    def B44 (var1 ,var2, var3, var4):
        return var3

    # Cmat
    def Cmat1 (var1, var2, var3, var4):
        return 0
    def Cmat2 (var1, var2, var3, var4):
        return  (np.sin(beta)*g*rho_l*var1 + tau_gl (var1, var2, var3, var4)*P_gl (var1)/A - tau_lw (var1, var2)*P_lw (var1)/A + Fbody*var1)/(rho_l*var1)
    def Cmat3 (var1, var2, var3, var4):
        return -np.sin(beta)*g + (tau_gl (var1, var2, var3, var4)*P_gl (var1)/A + tau_gw (var1, var3, var4)*P_gw (var1)/A + Fbody*(-1 + var1))/(rho_g (var4)*(-1 + var1))
    def Cmat4 (var1, var2, var3, var4):
        return 0

    # # Dmat
    # def Dmat (var1, var4, Gamma_l, Gamma_g, nu_l, nu_g):
    #     Dmat = [[rho_l*Gamma_l, 0, 0, 0],
        
    #             [-rho_g (var4)*Gamma_g, 0, 0, 0],
                
    #             [0, var1*nu_l, 0, 0],
                
    #             [0, 0, nu_g*(1 - var1), 0]]
    #     return Dmat

# ===============================================================
# 3 - QUASILINEAR SYSTEM 
# U = (alpha_l*rho_l, alpha_g*rho_g, alpha_l*rho_l*u_l, alpha_g*rho_g*u_g)
# A = I 
# ===============================================================
# Matrices
elif system == "system_3":
    # Amat
    def A11 (var1 ,var2, var3, var4):
        return 1
    def A12 (var1 ,var2, var3, var4):
        return 0
    def A13 (var1 ,var2, var3, var4):
        return 0
    def A14 (var1 ,var2, var3, var4):
        return 0

    def A21 (var1 ,var2, var3, var4):
        return 0
    def A22 (var1 ,var2, var3, var4):
        return 1
    def A23 (var1 ,var2, var3, var4):
        return 0
    def A24 (var1 ,var2, var3, var4):
        return 0

    def A31 (var1 ,var2, var3, var4):
        return 0
    def A32 (var1 ,var2, var3, var4):
        return 0
    def A33 (var1 ,var2, var3, var4):
        return 1
    def A34 (var1 ,var2, var3, var4):
        return 0

    def A41 (var1 ,var2, var3, var4):
        return 0
    def A42 (var1 ,var2, var3, var4):
        return 0
    def A43 (var1 ,var2, var3, var4):
        return 0
    def A44 (var1 ,var2, var3, var4):
        return 1

    # Bmat
    def B11 (var1 ,var2, var3, var4):
        return 0
    def B12 (var1 ,var2, var3, var4):
        return 0
    def B13 (var1 ,var2, var3, var4):
        return 1
    def B14 (var1 ,var2, var3, var4):
        return 0

    def B21 (var1 ,var2, var3, var4):
        return 0
    def B22 (var1 ,var2, var3, var4):
        return 0
    def B23 (var1 ,var2, var3, var4):
        return 0
    def B24 (var1 ,var2, var3, var4):
        return 1

    def B31 (var1 ,var2, var3, var4):
        return Dc (var1/rho_l)/rho_l + (var1*var2)/(p_factor*rho_l*(rho_l - var1)*(1 - var1/rho_l)) - var3**2/var1**2
    def B32 (var1 ,var2, var3, var4):
        return var1/(rho_l*(p_factor - (p_factor*var1)/rho_l))
    def B33 (var1 ,var2, var3, var4):
        return 2*var3/var1
    def B34 (var1 ,var2, var3, var4):
        return 0

    def B41 (var1 ,var2, var3, var4):
        return ((var2)/(p_factor*(1 - var1/rho_l)) + (Dc (var1/rho_l)*(p_factor - (p_factor*var1)/rho_l)*var2)/(p_factor*(1 - var1/rho_l)))/rho_l
    def B42 (var1 ,var2, var3, var4):
        return 1/p_factor - var4**2/var2**2
    def B43 (var1 ,var2, var3, var4):
        return 0
    def B44 (var1 ,var2, var3, var4):
        return 2*var4/var2

    # Cmat
    def Cmat1 (var1, var2, var3, var4):
        return 0
    def Cmat2 (var1, var2, var3, var4):
        return 0
    def Cmat3 (var1, var2, var3, var4):
        return g*np.sin (beta)*var1 + tau_lw (var1, var2)*P_lw (var1)/A + tau_gl (var1, var2, var3, var4)*P_gl (var1)/A
    def Cmat4 (var1, var2, var3, var4):
        return -(np.sin (beta)*g*(var1/rho_l - 1)*var2)/(1 - var1/rho_l) + tau_gw (var1, var3, var4)*P_gw (var1)/A - tau_gl (var1, var2, var3, var4)*P_gl (var1)/A

    # # # Dmat
    # # def Dmat (var1, var4, Gamma_l, Gamma_g, nu_l, nu_g):
    # #     Dmat = [[rho_l*Gamma_l, 0, 0, 0],
        
    # #             [-rho_g (var4)*Gamma_g, 0, 0, 0],
                
    # #             [0, var1*nu_l, 0, 0],
                
    # #             [0, 0, nu_g*(1 - var1), 0]]
    # #     return Dmat
