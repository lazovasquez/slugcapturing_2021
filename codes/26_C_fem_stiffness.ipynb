# %% [markdown]
# ## VARIABLES: numerical solution
#
# - variable1: liquid volume fraction (alpha_l)
# - variable2: liquid velocity (u_l)
# - variable3: gas velocity (u_g)
# - variable4: interfacial pressure (p_i)

# %%
# Import libraries
# %run ./00_libraries.ipynb
# %run ./01_constants.ipynb
# %run ./04_C_testcases.ipynb
# %run ./05_testcases_conditions.ipynb
# %run ./06_equations_functions.ipynb
# %run ./07_equations_matrices.ipynb
# %run ./08_stability_functions.ipynb
# %run ./09_reference_conditions.ipynb

# %run ./16_fem_discretization.ipynb
# %run ./17_initial_boundary_conditions.ipynb
# %run ./18_variational_form.ipynb
# %run ./19_solvers.ipynb
# Out:
# Equation system : system_2 , case : case0 , configuration : horizontal
#
#  ======================================================================
#
# INFO: var1_ref =  0.5029558947324747 [-]
# INFO: var2_ref =  0.09941229543913647 [m/s]
# INFO: var3_ref =  1.6678600373981 [m/s]
# INFO: var4_ref =  100000.0 [Pa]
#
# INFO: Rel_ref  =  5713.454556627368 [-]
# INFO: Reg_ref  =  3339.735050374323 [-]
#
# Re [lambda] = [295.2684087686211, -291.9363712006974, -0.33930085419437056, 0.5418079519407015]
# Im [lambda] = [0.0, 0.0, 0.0, 0.0]
#
# max (Re [lambda]) = 295.2684087686211
#
# INFO: well-posed
#
# Re [omega] = [1855.2258088024682, -1834.2899992732116, -2.1299311570679405, 3.402320738772644]
# Im [omega] = [1.0792973669448125, 1.079922302991717, 0.10924925714399916, 0.09923855956611964]
#
# INFO: VKH stable
# INFO: elementspace =  TaylorHood
# INFO: deg1 =  1
# INFO: deg2 =  2
# INFO: deg3 =  2
# INFO: deg4 =  1

# %%
# %run ./20_semi_discretized.ipynb
# Out:
# Condition number: 6.517252325323758e+17
# Max Real -0.0011296410295405662
# Min Real -0.01588717239247092
# Max Imag 391.2662381498753
# Min Imag -391.2662381498753
# A_sparray =    (0, 0)	-0.04970614771956824
#   (0, 1)	0.04970614771956824
#   (0, 2)	0.08382598245541248
#   (0, 3)	0.0
#   (0, 4)	0.0
#   (0, 5)	-0.4191299122770622
#   (0, 6)	0.3353039298216498
#   (0, 7)	0.0
#   (0, 8)	0.0
#   (0, 9)	0.0
#   (1, 0)	-0.04970614771956824
#   (1, 1)	0.0
#   (1, 2)	0.0
#   (1, 3)	0.0
#   (1, 4)	0.0
#   (1, 5)	-0.08382598245541248
#   (1, 6)	-0.3353039298216498
#   (1, 7)	0.0
#   (1, 8)	0.0
#   (1, 9)	0.0
#   (1, 10)	0.04970614771956824
#   (1, 11)	0.08382598245541248
#   (1, 12)	0.0
#   (1, 13)	0.0
#   (1, 14)	0.3353039298216498
#   :	:
#   (241, 239)	0.003676352710394435
#   (241, 240)	0.0018381763551972184
#   (241, 241)	0.8267164175219884
#   (241, 242)	-1.115513492187264
#   (241, 243)	0.14350194977757452
#   (242, 232)	-0.2525580066283701
#   (242, 233)	0.0018381763551972184
#   (242, 234)	-1.1155134921872645
#   (242, 235)	-0.5740077494448509
#   (242, 238)	0.27083696733701196
#   (242, 239)	0.0018381763551972184
#   (242, 240)	0.014705410841577756
#   (242, 241)	1.1082998910102027
#   (242, 242)	-0.028854404708246816
#   (242, 243)	0.5740077825551492
#   (243, 232)	157777.52168640788
#   (243, 233)	-16864.898218699247
#   (243, 234)	-16666.66666666667
#   (243, 235)	-0.8339300186990501
#   (243, 238)	-157777.52168640788
#   (243, 239)	84324.49109349621
#   (243, 240)	-67459.59287479697
#   (243, 241)	83333.33333333333
#   (243, 242)	-66666.66666666666
#   (243, 243)	0.8339300186990501
