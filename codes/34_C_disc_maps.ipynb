# %% [markdown]
# # Input codes
# > Import notebooks

# %%
# %run ./00_libraries.ipynb
# %run ./01_constants_codes.ipynb
# %run ./02_constants_test_cases.ipynb

# %run ./05_C_testcases.ipynb
# %run ./06_testcases_conditions.ipynb
# %run ./07_equations_functions.ipynb
# %run ./08_equations_matrices.ipynb

# %run ./10_stability_functions.ipynb
# Out:
# Inclination =  horizontal
# INFO: case1 horizontal unstable (Sanderse et al., 2017)
# Diameter =  0.078
# Validation =  KH instabilities based (Sanderse et al., 2017)
# INFO: BDF1 first-order Backward differentiation formula time integration.

# %% [markdown]
# # Well-posedness maps
#
# > IKH curves.

# %%
# %run ./12_stability_maps_well_posedness.ipynb
# Out:
#  >>> β = 0.0 deg
#  >>> β = 0.25 deg
#  >>> β = -5.0 deg
#  >>> β =  0.0 deg
#  >>> β =  0.25 deg
#  >>> β =  -5.0 deg

# %% [markdown]
# # Fourier analysis
#
# > IKH and VKH + discrete flow pattern maps + validation curves.

# %%
# %run ./14_stability_maps_fourier.ipynb
# %run ./25_stability_maps_fourier_discrete.ipynb
# Out:
#   >>> β =  0.0 [°]
# INFO: T =  0.025
# INFO: dt =  0.025
# INFO: steps =  1
# INFO: elementspace =  TaylorHood
# INFO: deg1 =  1
# INFO: deg2 =  2
# INFO: deg3 =  2
# INFO: deg4 =  1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Desktop/Github/slugcapturing/codes/20_variational_form.ipynb in <module>
#      67
#      68         # Cmat coefficient
# ---> 69         C11_ref = Constant (Ceval[0][0])
#      70         C12_ref = Constant (Ceval[0][1])
#      71         C13_ref = Constant (Ceval[0][2])
#
# NameError: name 'Ceval' is not defined
# variable1_n =  [0.47866183 0.47866183 0.47866183 0.47866183 0.47866183 0.47866183
#  0.47866183 0.47866183 0.47866183 0.47866183 0.47866183 0.47866183
#  0.47866183 0.47866183 0.47866183 0.47866183 0.47866183 0.47866183
#  0.47866183 0.47866183 0.47866183 0.47866183 0.47866183 0.47866183
#  0.47866183 0.47866183 0.47866183 0.47866183 0.47866183 0.47866183
#  0.47866183 0.47866183 0.47866183 0.47866183 0.47866183 0.47866183
#  0.47866183 0.47866183 0.47866183 0.47866183 0.47866183]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Desktop/Github/slugcapturing/codes/25_stability_maps_fourier_discrete.ipynb in <module>
#     229
#     230                         # Variational form
# --> 231                         F = visc*Cm - Bm
#     232                         F_n = visc*Cm_n - Bm_n
#     233                         R = Am - theta*F - (1 - theta)*F_n
#
# NameError: name 'Cm' is not defined
