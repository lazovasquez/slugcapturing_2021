# %%
# Import libraries
# %run ./00_libraries.ipynb
# %run ./01_constants.ipynb
# %run ./04_C_testcases.ipynb
# %run ./05_testcases_conditions.ipynb
# %run ./06_equations_functions.ipynb
# %run ./07_equations_matrices.ipynb















# %run ./0_libraries.ipynb
# %run ./1_constants_functions.ipynb
# %run ./2_testcases.ipynb
# %run ./3_testcases_conditions.ipynb

# %run ./4_functions_equations.ipynb
# %run ./5_equations_matrices.ipynb
# %run ./6_stability

# %run ./10_fem.ipynb
# %run ./11_initial_boundary_conditions.ipynb
# %run ./12_variational_form.ipynb
# %run ./13_solvers.ipynb
# %run ./14_semi_discretized.ipynb
# Out:
# Equation system : system_1 , case : case1 , configuration : horizontal
#
# ...
#
# INFO: var1_ref =  0.4971621132437725 [-]
# INFO: var2_ref =  0.10057081718027777 [m/s]
# INFO: var3_ref =  1.6486426775592065 [m/s]
# INFO: var4_ref =  100000.0 [Pa]
#
# INFO: Rel_ref  =  8788.978418008168 [-]
# INFO: Reg_ref  =  5089.783701836487 [-]
# INFO: Regl_ref =  4779.2957391432055 [-]
#
# Re [lambda] = [295.24530881141357, -291.95157496005584, -0.4408329351046529, 0.6455260732725726]
# Im [lambda] = [0.0, 0.0, 0.0, 0.0]
#
# max (Re [lambda]) = 295.24530881141357
#
# INFO: well-posed
#
# Re [omega] = [1855.0808658557996, -1834.385725703953, -2.769252570227837, 4.055377476911392]
# Im [omega] = [0.6653161131502013, 0.6618485451416974, 0.06613355443564206, 0.06011237508821993]
#
# INFO: VKH stable

# %% [markdown]
# ## VARIABLES: numerical solution
#
# - variable1: liquid volume fraction (alpha_l)
# - variable2: liquid velocity (u_l)
# - variable3: gas velocity (u_g)
# - variable4: interfacial pressure (p_i)

# %%
# %run ./13_variational_form.ipynb
# %run ./14_solvers.ipynb
# %run ./15_semi_discretized.ipynb
# %run ./16_fully_discretized.ipynb
# Out:
# Condition number: 1.1791074577748118e+17
# Max Real 36.13228839709154
# Min Real -36.15059360094671
# Max Imag 95.77577634255714
# Min Imag -95.77577634255714
# A_sparray =    (0, 0)	-50.285408590138886
#   (0, 1)	50.285408590138886
#   (0, 2)	82.86035220729545
#   (0, 3)	0.0
#   (0, 4)	0.0
#   (0, 5)	-414.30176103647705
#   (0, 6)	331.4414088291817
#   (0, 7)	0.0
#   (0, 8)	0.0
#   (0, 9)	0.0
#   (1, 0)	-50.285408590138886
#   (1, 1)	0.0
#   (1, 2)	0.0
#   (1, 3)	0.0
#   (1, 4)	0.0
#   (1, 5)	-82.86035220729545
#   (1, 6)	-331.4414088291817
#   (1, 7)	0.0
#   (1, 8)	0.0
#   (1, 9)	0.0
#   (1, 10)	50.285408590138886
#   (1, 11)	82.86035220729545
#   (1, 12)	0.0
#   (1, 13)	0.0
#   (1, 14)	331.4414088291817
#   :	:
#   (241, 239)	49.79578422280578
#   (241, 240)	-66.76877455526378
#   (241, 241)	0.0013696199521982084
#   (241, 242)	0.0006848099760991044
#   (241, 243)	0.08286036545898358
#   (242, 232)	-205.72943079576964
#   (242, 233)	-66.76877455526379
# ...
