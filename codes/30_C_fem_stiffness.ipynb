# %% [markdown]
# ## VARIABLES: numerical solution
#
# - variable1: liquid volume fraction (alpha_l)
# - variable2: liquid velocity (u_l)
# - variable3: gas velocity (u_g)
# - variable4: interfacial pressure (p_i)

# %%
# Import libraries
# %run ./00_libraries.ipynb
# %run ./01_constants.ipynb
# %run ./04_C_testcases.ipynb
# %run ./05_testcases_conditions.ipynb
# %run ./06_equations_functions.ipynb
# %run ./07_equations_matrices.ipynb
# %run ./08_stability_functions.ipynb
# %run ./09_reference_conditions.ipynb

# %run ./16_fem_discretization.ipynb
# %run ./17_initial_boundary_conditions.ipynb
# %run ./18_variational_form.ipynb
# %run ./19_solvers.ipynb
# Out:
# Inclination =  horizontal
# INFO: case0 horizontal stable (Sanderse et al., 2017)
# Diameter =  0.078
# Validation =  KH instabilities based (Sanderse et al., 2017)
# Equation system : system_2 , case : case0 , configuration : horizontal
#
#  ======================================================================
#
# INFO: var1_ref =  0.4971621132437725 [-]
# INFO: var2_ref =  0.10057081718027777 [m/s]
# INFO: var3_ref =  1.6486426775592065 [m/s]
# INFO: var4_ref =  100000.0 [Pa]
#
# INFO: Rel_ref  =  8788.978418008168 [-]
# INFO: Reg_ref  =  5089.783701836487 [-]
#
# Re [lambda] = [295.2453088128787, -291.951574961584, -0.440832935104544, 0.6455260732730961]
# Im [lambda] = [0.0, 0.0, 0.0, 0.0]
#
# max (Re [lambda]) = 295.2453088128787
#
# INFO: well-posed
#
# Re [omega] = [1855.0808658526807, -1834.3857256976291, -2.769252138384073, 4.055377041770045]
# Im [omega] = [0.663400423190985, 0.6637642015843525, 0.06559040693580517, 0.06065555607305187]
#
# INFO: VKH stable
# INFO: elementspace =  TaylorHood
# INFO: deg1 =  1
# INFO: deg2 =  2
# INFO: deg3 =  2
# INFO: deg4 =  1

# %%
# %run ./20_semi_discretized.ipynb
# Out:
# Max Real -0.0001703874215371326
# Min Real -0.001912821468810378
# Max Imag 391.474528863217
# Min Imag -391.474528863217
